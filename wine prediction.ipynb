# %%
#Libraries we will use
import numpy as np
import warnings
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from math import sqrt
from sklearn import metrics
# %matplotlib inline
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier

# %%
#importing the dataset
dataset = pd.read_csv("winequality-red.csv")

# %%
#seeing first 10 values of dataset 
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
#checking the shape of dataset to see the number of rows and columns
dataset.shape
# Out:
# (1599, 12)

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#checking for missing values
print(dataset.isna().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#visualizing different wine qualities and how many wines have that rating in the data set 
sns.countplot(dataset['quality'])
dataset['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
#correaltion matrix
plt.figure(figsize=(10,6))
sns.heatmap(dataset.corr(), annot=True, fmt='.0%')

# %%
#making a copy of our dataframe and grouping quality into different groups
dataset_aux = dataset.copy()
dataset_aux['quality'].replace([3,4],['low','low'],inplace=True)
dataset_aux['quality'].replace([5,6],['med','med'],inplace=True)
dataset_aux['quality'].replace([7,8],['high','high'],inplace=True)
sns.countplot(dataset_aux['quality'])

# %%
# Create Classification version of target variable
dataset['goodquality'] = [1 if x >= 7 else 0 for x in dataset['quality']]
# Separate feature variables and target variable
X = dataset.drop(['quality','goodquality'], axis = 1)
y = dataset['goodquality']

# %%
# See proportion of good vs bad wines
dataset['goodquality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: goodquality, dtype: int64

# %%
sns.countplot(dataset['quality'])

# %%
# Normalize feature variables
from sklearn.preprocessing import StandardScaler
X_features = X
X = StandardScaler().fit_transform(X)

# %%
# Splitting the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state=0)

# %%
model1 = DecisionTreeClassifier(random_state=1)
model1.fit(X_train, y_train)
y_pred1 = model1.predict(X_test)
print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       355
#            1       0.53      0.73      0.62        45
#
#     accuracy                           0.90       400
#    macro avg       0.75      0.83      0.78       400
# weighted avg       0.92      0.90      0.90       400

# %%
RMSE = sqrt(mean_squared_error(y_test, y_pred1))
print(RMSE)
# Out:
# 0.32015621187164245

# %%
# Filtering dataset for only good quality
dataset_temp = dataset[dataset['goodquality']==1]
dataset_temp.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count     217.000000        217.000000   217.000000      217.000000
# mean        8.847005          0.405530     0.376498        2.708756
# std         1.999977          0.144963     0.194438        1.363026
# min         4.900000          0.120000     0.000000        1.200000
# 25%         7.400000          0.300000     0.300000        2.000000
# 50%         8.700000          0.370000     0.400000        2.300000
# 75%        10.100000          0.490000     0.490000        2.700000
# max        15.600000          0.915000     0.760000        8.900000
#
#         chlorides  free sulfur dioxide  total sulfur dioxide     density  \
# count  217.000000           217.000000            217.000000  217.000000
# mean     0.075912            13.981567             34.889401    0.996030
# std      0.028480            10.234615             32.572238    0.002201
# ...

# %%
# Filtering dataset for only bad quality
dataset_temp2 = dataset[dataset['goodquality']==0]
dataset_temp2.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1382.000000       1382.000000  1382.000000     1382.000000
# mean        8.236831          0.547022     0.254407        2.512120
# std         1.682726          0.176337     0.189665        1.415778
# min         4.600000          0.160000     0.000000        0.900000
# 25%         7.100000          0.420000     0.082500        1.900000
# 50%         7.800000          0.540000     0.240000        2.200000
# 75%         9.100000          0.650000     0.400000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1382.000000          1382.000000           1382.000000  1382.000000
# mean      0.089281            16.172214             48.285818     0.996859
# std       0.049113            10.467685             32.585604     0.001808
# ...
